# %% [markdown]
# # 0 - Imports

# %%
# Manejo de datos
import pandas as pd
import numpy as np
import os

# Visualización de datos
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# Red Neuronal
from tensorflow.keras import models
from tensorflow.keras import layers

# MLFlow
import mlflow

# Utilidades
import sys
sys.path.append("..\..")
from package_utilities import mlflow_utils as mlf
from joblib import dump # Gurdado local modelo

# %% [markdown]
# # 1- Cargar de datos

# %%
X_train = pd.read_parquet("../../data/train_set_test/TfidfVectorizer/X_train.parquet")
X_val = pd.read_parquet("../../data/train_set_test/TfidfVectorizer/X_val.parquet")
Y_train = pd.read_parquet("../../data/train_set_test/TfidfVectorizer/Y_train.parquet")
Y_val = pd.read_parquet("../../data/train_set_test/TfidfVectorizer/Y_val.parquet")

# %%
# Creación conjunto Test
X_test = X_val[-50:]
X_val = X_val[:-50]

Y_test = Y_val[-50:]
Y_val = Y_val[:-50]

# %% [markdown]
# # 2- Construcción del modelo

# %%
name = "4_Keras"

# %%
# Estructura
model = models.Sequential()

model.add(layers.Dense(120, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
# Parámetros
model.compile(
    optimizer='adam', 
    loss='binary_crossentropy',
    metrics=['accuracy', 'Precision']
)

# %%
# Entrenamiento
history = model.fit(
    X_train,
    Y_train,
    epochs=60,
    batch_size=512,
    validation_data=(X_val, Y_val))
# Out:
# Epoch 1/60
# 13/13 [==============================] - 5s 216ms/step - loss: 0.6869 - accuracy: 0.5557 - precision: 0.3893 - val_loss: 0.6768 - val_accuracy: 0.5723 - val_precision: 0.0000e+00
# Epoch 2/60
# 13/13 [==============================] - 1s 94ms/step - loss: 0.6564 - accuracy: 0.5713 - precision: 1.0000 - val_loss: 0.6377 - val_accuracy: 0.5797 - val_precision: 1.0000
# Epoch 3/60
# 13/13 [==============================] - 1s 90ms/step - loss: 0.5675 - accuracy: 0.6795 - precision: 0.9707 - val_loss: 0.5602 - val_accuracy: 0.7482 - val_precision: 0.9174
# Epoch 4/60
# 13/13 [==============================] - 1s 90ms/step - loss: 0.4079 - accuracy: 0.8731 - precision: 0.9450 - val_loss: 0.5099 - val_accuracy: 0.7830 - val_precision: 0.7819
# Epoch 5/60
# 13/13 [==============================] - 1s 104ms/step - loss: 0.2450 - accuracy: 0.9305 - precision: 0.9331 - val_loss: 0.5582 - val_accuracy: 0.7775 - val_precision: 0.7511
# Epoch 6/60
# 13/13 [==============================] - 1s 93ms/step - loss: 0.1412 - accuracy: 0.9563 - precision: 0.9535 - val_loss: 0.6682 - val_accuracy: 0.7665 - val_precision: 0.7227
# Epoch 7/60
# 13/13 [==============================] - 1s 88ms/step - loss: 0.0938 - accuracy: 0.9714 - precision: 0.9669 - val_loss: 0.7415 - val_accuracy: 0.7701 - val_precision: 0.7432
# Epoch 8/60
# 13/13 [==============================] - 1s 92ms/step - loss: 0.0702 - accuracy: 0.9770 - precision: 0.9724 - val_loss: 0.7971 - val_accuracy: 0.7619 - val_precision: 0.7326
# Epoch 9/60
# 13/13 [==============================] - 1s 105ms/step - loss: 0.0600 - accuracy: 0.9808 - precision: 0.9770 - val_loss: 0.8499 - val_accuracy: 0.7592 - val_precision: 0.7287
# Epoch 10/60
# 13/13 [==============================] - 1s 96ms/step - loss: 0.0512 - accuracy: 0.9828 - precision: 0.9799 - val_loss: 0.8820 - val_accuracy: 0.7573 - val_precision: 0.7225
# Epoch 11/60
# 13/13 [==============================] - 1s 85ms/step - loss: 0.0487 - accuracy: 0.9811 - precision: 0.9743 - val_loss: 0.9219 - val_accuracy: 0.7656 - val_precision: 0.7542
# Epoch 12/60
# 13/13 [==============================] - 1s 84ms/step - loss: 0.0466 - accuracy: 0.9827 - precision: 0.9809 - val_loss: 0.9352 - val_accuracy: 0.7381 - val_precision: 0.6843
# Epoch 13/60
# 13/13 [==============================] - 1s 89ms/step - loss: 0.0374 - accuracy: 0.9858 - precision: 0.9855 - val_loss: 0.9765 - val_accuracy: 0.7647 - val_precision: 0.7500
# Epoch 14/60
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0381 - accuracy: 0.9859 - precision: 0.9842 - val_loss: 0.9899 - val_accuracy: 0.7546 - val_precision: 0.7187
# Epoch 15/60
# 13/13 [==============================] - 1s 90ms/step - loss: 0.0375 - accuracy: 0.9861 - precision: 0.9866 - val_loss: 1.0009 - val_accuracy: 0.7619 - val_precision: 0.7235
# Epoch 16/60
# 13/13 [==============================] - 1s 85ms/step - loss: 0.0399 - accuracy: 0.9852 - precision: 0.9817 - val_loss: 1.0166 - val_accuracy: 0.7555 - val_precision: 0.7212
# Epoch 17/60
# 13/13 [==============================] - 1s 96ms/step - loss: 0.0370 - accuracy: 0.9864 - precision: 0.9852 - val_loss: 1.0166 - val_accuracy: 0.7454 - val_precision: 0.6989
# Epoch 18/60
# 13/13 [==============================] - 1s 87ms/step - loss: 0.0336 - accuracy: 0.9858 - precision: 0.9828 - val_loss: 1.0416 - val_accuracy: 0.7564 - val_precision: 0.7410
# Epoch 19/60
# 13/13 [==============================] - 1s 84ms/step - loss: 0.0358 - accuracy: 0.9858 - precision: 0.9863 - val_loss: 1.0365 - val_accuracy: 0.7564 - val_precision: 0.7269
# Epoch 20/60
# 13/13 [==============================] - 1s 94ms/step - loss: 0.0314 - accuracy: 0.9866 - precision: 0.9831 - val_loss: 1.0473 - val_accuracy: 0.7546 - val_precision: 0.7196
# Epoch 21/60
# 13/13 [==============================] - 1s 84ms/step - loss: 0.0321 - accuracy: 0.9870 - precision: 0.9870 - val_loss: 1.0634 - val_accuracy: 0.7573 - val_precision: 0.7275
# Epoch 22/60
# 13/13 [==============================] - 1s 85ms/step - loss: 0.0322 - accuracy: 0.9869 - precision: 0.9877 - val_loss: 1.0717 - val_accuracy: 0.7463 - val_precision: 0.7030
# Epoch 23/60
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0317 - accuracy: 0.9867 - precision: 0.9873 - val_loss: 1.0797 - val_accuracy: 0.7573 - val_precision: 0.7338
# Epoch 24/60
# 13/13 [==============================] - 1s 84ms/step - loss: 0.0306 - accuracy: 0.9864 - precision: 0.9856 - val_loss: 1.0873 - val_accuracy: 0.7573 - val_precision: 0.7295
# Epoch 25/60
# 13/13 [==============================] - 1s 93ms/step - loss: 0.0321 - accuracy: 0.9861 - precision: 0.9845 - val_loss: 1.0863 - val_accuracy: 0.7555 - val_precision: 0.7242
# Epoch 26/60
# 13/13 [==============================] - 1s 85ms/step - loss: 0.0274 - accuracy: 0.9884 - precision: 0.9895 - val_loss: 1.1009 - val_accuracy: 0.7601 - val_precision: 0.7423
# Epoch 27/60
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0293 - accuracy: 0.9872 - precision: 0.9877 - val_loss: 1.1056 - val_accuracy: 0.7637 - val_precision: 0.7370
# Epoch 28/60
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0290 - accuracy: 0.9873 - precision: 0.9860 - val_loss: 1.1095 - val_accuracy: 0.7491 - val_precision: 0.7066
# Epoch 29/60
# 13/13 [==============================] - 1s 82ms/step - loss: 0.0268 - accuracy: 0.9875 - precision: 0.9874 - val_loss: 1.1234 - val_accuracy: 0.7555 - val_precision: 0.7273
# Epoch 30/60
# 13/13 [==============================] - 1s 91ms/step - loss: 0.0281 - accuracy: 0.9872 - precision: 0.9874 - val_loss: 1.1267 - val_accuracy: 0.7537 - val_precision: 0.7271
# Epoch 31/60
# 13/13 [==============================] - 1s 87ms/step - loss: 0.0271 - accuracy: 0.9889 - precision: 0.9892 - val_loss: 1.1446 - val_accuracy: 0.7546 - val_precision: 0.7177
# Epoch 32/60
# 13/13 [==============================] - 1s 87ms/step - loss: 0.0288 - accuracy: 0.9867 - precision: 0.9859 - val_loss: 1.1549 - val_accuracy: 0.7573 - val_precision: 0.7254
# Epoch 33/60
# 13/13 [==============================] - 1s 89ms/step - loss: 0.0268 - accuracy: 0.9875 - precision: 0.9881 - val_loss: 1.1674 - val_accuracy: 0.7601 - val_precision: 0.7446
# Epoch 34/60
# 13/13 [==============================] - 1s 88ms/step - loss: 0.0265 - accuracy: 0.9887 - precision: 0.9899 - val_loss: 1.1619 - val_accuracy: 0.7573 - val_precision: 0.7235
# Epoch 35/60
# 13/13 [==============================] - 1s 94ms/step - loss: 0.0276 - accuracy: 0.9864 - precision: 0.9859 - val_loss: 1.1665 - val_accuracy: 0.7592 - val_precision: 0.7267
# Epoch 36/60
# 13/13 [==============================] - 1s 87ms/step - loss: 0.0267 - accuracy: 0.9870 - precision: 0.9877 - val_loss: 1.1770 - val_accuracy: 0.7573 - val_precision: 0.7327
# Epoch 37/60
# 13/13 [==============================] - 1s 84ms/step - loss: 0.0244 - accuracy: 0.9879 - precision: 0.9891 - val_loss: 1.1927 - val_accuracy: 0.7601 - val_precision: 0.7335
# Epoch 38/60
# 13/13 [==============================] - 1s 83ms/step - loss: 0.0268 - accuracy: 0.9887 - precision: 0.9902 - val_loss: 1.1970 - val_accuracy: 0.7592 - val_precision: 0.7318
# Epoch 39/60
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0256 - accuracy: 0.9870 - precision: 0.9881 - val_loss: 1.1994 - val_accuracy: 0.7555 - val_precision: 0.7262
# Epoch 40/60
# 13/13 [==============================] - 1s 83ms/step - loss: 0.0247 - accuracy: 0.9875 - precision: 0.9853 - val_loss: 1.2191 - val_accuracy: 0.7564 - val_precision: 0.7289
# Epoch 41/60
# 13/13 [==============================] - 1s 92ms/step - loss: 0.0249 - accuracy: 0.9876 - precision: 0.9895 - val_loss: 1.2328 - val_accuracy: 0.7564 - val_precision: 0.7376
# Epoch 42/60
# 13/13 [==============================] - 1s 88ms/step - loss: 0.0253 - accuracy: 0.9873 - precision: 0.9888 - val_loss: 1.2233 - val_accuracy: 0.7601 - val_precision: 0.7314
# Epoch 43/60
# 13/13 [==============================] - 1s 88ms/step - loss: 0.0244 - accuracy: 0.9875 - precision: 0.9874 - val_loss: 1.2472 - val_accuracy: 0.7592 - val_precision: 0.7350
# Epoch 44/60
# 13/13 [==============================] - 1s 79ms/step - loss: 0.0261 - accuracy: 0.9879 - precision: 0.9884 - val_loss: 1.2399 - val_accuracy: 0.7592 - val_precision: 0.7318
# Epoch 45/60
# 13/13 [==============================] - 1s 92ms/step - loss: 0.0244 - accuracy: 0.9889 - precision: 0.9895 - val_loss: 1.2534 - val_accuracy: 0.7582 - val_precision: 0.7377
# Epoch 46/60
# 13/13 [==============================] - 1s 93ms/step - loss: 0.0223 - accuracy: 0.9886 - precision: 0.9895 - val_loss: 1.2764 - val_accuracy: 0.7582 - val_precision: 0.7312
# Epoch 47/60
# 13/13 [==============================] - 1s 84ms/step - loss: 0.0247 - accuracy: 0.9872 - precision: 0.9870 - val_loss: 1.2839 - val_accuracy: 0.7592 - val_precision: 0.7267
# Epoch 48/60
# 13/13 [==============================] - 1s 83ms/step - loss: 0.0229 - accuracy: 0.9887 - precision: 0.9881 - val_loss: 1.3063 - val_accuracy: 0.7619 - val_precision: 0.7401
# Epoch 49/60
# 13/13 [==============================] - 1s 85ms/step - loss: 0.0229 - accuracy: 0.9879 - precision: 0.9895 - val_loss: 1.3216 - val_accuracy: 0.7582 - val_precision: 0.7355
# Epoch 50/60
# 13/13 [==============================] - 1s 96ms/step - loss: 0.0227 - accuracy: 0.9889 - precision: 0.9909 - val_loss: 1.3285 - val_accuracy: 0.7582 - val_precision: 0.7261
# Epoch 51/60
# 13/13 [==============================] - 1s 87ms/step - loss: 0.0241 - accuracy: 0.9870 - precision: 0.9863 - val_loss: 1.3310 - val_accuracy: 0.7601 - val_precision: 0.7314
# Epoch 52/60
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0224 - accuracy: 0.9876 - precision: 0.9888 - val_loss: 1.3316 - val_accuracy: 0.7592 - val_precision: 0.7361
# Epoch 53/60
# 13/13 [==============================] - 1s 86ms/step - loss: 0.0242 - accuracy: 0.9884 - precision: 0.9909 - val_loss: 1.3464 - val_accuracy: 0.7610 - val_precision: 0.7384
# Epoch 54/60
# 13/13 [==============================] - 1s 84ms/step - loss: 0.0230 - accuracy: 0.9876 - precision: 0.9877 - val_loss: 1.3283 - val_accuracy: 0.7546 - val_precision: 0.7168
# Epoch 55/60
# 13/13 [==============================] - 1s 92ms/step - loss: 0.0224 - accuracy: 0.9881 - precision: 0.9863 - val_loss: 1.3548 - val_accuracy: 0.7592 - val_precision: 0.7308
# Epoch 56/60
# 13/13 [==============================] - 1s 84ms/step - loss: 0.0228 - accuracy: 0.9879 - precision: 0.9906 - val_loss: 1.3753 - val_accuracy: 0.7601 - val_precision: 0.7482
# Epoch 57/60
# 13/13 [==============================] - 1s 85ms/step - loss: 0.0227 - accuracy: 0.9884 - precision: 0.9902 - val_loss: 1.3683 - val_accuracy: 0.7546 - val_precision: 0.7256
# Epoch 58/60
# 13/13 [==============================] - 1s 83ms/step - loss: 0.0213 - accuracy: 0.9872 - precision: 0.9884 - val_loss: 1.3817 - val_accuracy: 0.7555 - val_precision: 0.7262
# Epoch 59/60
# 13/13 [==============================] - 1s 82ms/step - loss: 0.0229 - accuracy: 0.9872 - precision: 0.9877 - val_loss: 1.4006 - val_accuracy: 0.7555 - val_precision: 0.7193
# Epoch 60/60
# 13/13 [==============================] - 1s 87ms/step - loss: 0.0212 - accuracy: 0.9892 - precision: 0.9885 - val_loss: 1.4342 - val_accuracy: 0.7564 - val_precision: 0.7199

# %% [markdown]
# ## Visualización entrenamiento

# %%
print("Los valores finales son")
pd.DataFrame(history.history)[-1:]
# Out:
# Los valores finales son
#         loss  accuracy  precision  val_loss  val_accuracy  val_precision
# 59  0.021178  0.989183   0.988464  1.434209       0.75641       0.719912

# %%
from package_utilities import grafics_utils

df = pd.DataFrame(history.history)[['loss', 'val_loss']]
loss_grafic = grafics_utils.evolution_keras_train(df)

# %%
df = pd.DataFrame(history.history)[['accuracy', 'val_accuracy']]
accuracy_grafic = grafics_utils.evolution_keras_train(df)

# %%
df = pd.DataFrame(history.history)[['precision', 'val_precision']]
precision_grafic = grafics_utils.evolution_keras_train(df)

# %% [markdown]
# ## Test

# %%
from package_utilities import evaluate_model
Y_pred = model.predict(X_test).round(0)
evaluate_model(Y_pred, Y_test)
# Out:
# 2/2 [==============================] - 0s 11ms/step
# Precisión: 0.8571428571428571
# Recall: 0.75
# Accuracy: 0.82
# F1 score: 0.7999999999999999
# AUC: 0.8173076923076922
# (0.8571428571428571,
#  0.75,
#  0.82,
#  0.7999999999999999,
#  0.8173076923076922,
#  <Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # 3- Evaluación del modelo

# %%
X_test = pd.read_csv("../../data/originals/test.csv")
X_test_vectorized = pd.read_parquet("../../data/modifications/TfidfVectorizer/X_test.parquet")

Y_pred = model.predict(X_test_vectorized).round(0)
Y_pred
# Out:
# 102/102 [==============================] - 1s 7ms/step
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [0.],
#        [1.]], dtype=float32)

# %%
for i in range(30):
    print("{} - {}".format(X_test['text'][i], Y_pred[i]))
# Out:
# Just happened a terrible car crash - [1.]
# Heard about #earthquake is different cities, stay safe everyone. - [1.]
# there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all - [1.]
# Apocalypse lighting. #Spokane #wildfires - [1.]
# Typhoon Soudelor kills 28 in China and Taiwan - [1.]
# We're shaking...It's an earthquake - [1.]
# They'd probably still show more life than Arsenal did yesterday, eh? EH? - [0.]
# Hey! How are you? - [0.]
# What a nice hat? - [0.]
# Fuck off! - [0.]
# No I don't like cold! - [0.]
# NOOOOOOOOO! Don't do that! - [0.]
# No don't tell me that! - [1.]
# What if?! - [0.]
# Awesome! - [0.]
# Birmingham Wholesale Market is ablaze BBC News - Fire breaks out at Birmingham's Wholesale Market http://t.co/irWqCEZWEU - [1.]
# @sunkxssedharry will you wear shorts for race ablaze ? - [0.]
# #PreviouslyOnDoyinTv: Toke MakinwaÛªs marriage crisis sets Nigerian Twitter ablaze... http://t.co/CMghxBa2XI - [1.]
# Check these out: http://t.co/rOI2NSmEJJ http://t.co/3Tj8ZjiN21 http://t.co/YDUiXEfIpE http://t.co/LxTjc87KLS #nsfw - [0.]
# PSA: IÛªm splitting my personalities.
#
# ?? techies follow @ablaze_co
# ?? Burners follow @ablaze - [0.]
# beware world ablaze sierra leone &amp; guap. - [0.]
# Burning Man Ablaze! by Turban Diva http://t.co/hodWosAmWS via @Etsy - [0.]
# Not a diss song. People will take 1 thing and run with it. Smh it's an eye opener though. He is about 2 set the game ablaze @CyhiThePrynce - [1.]
# Rape victim dies as she sets herself ablaze: A 16-year-old girl died of burn injuries as she set herself ablazeÛ_ http://t.co/UK8hNrbOob - [1.]
# SETTING MYSELF ABLAZE http://t.co/6vMe7P5XhC - [0.]
# @CTVToronto the bins in front of the field by my house wer set ablaze the other day flames went rite up the hydro pole wonder if it was him - [1.]
# #nowplaying Alfons - Ablaze 2015 on Puls Radio #pulsradio http://t.co/aA5BJgWfDv - [0.]
# 'Burning Rahm': Let's hope City Hall builds a giant wooden mayoral effigy 100 feet tall &amp; sets it ablaze. http://t.co/kFo2mksn6Y @John_Kass - [0.]
# @PhilippaEilhart @DhuBlath hurt but her eyes ablaze with insulted anger. - [0.]
# Accident cleared in #PaTurnpike on PATP EB between PA-18 and Cranberry slow back to #traffic http://t.co/SL0Oqn0Vyr - [1.]

# %% [markdown]
# # 4 - Registro del modelo

# %% [markdown]
# ### MLFlow

# %%
from package_utilities import mlflow_utils as mlf

def cargar_MLFlow():
    with mlflow.start_run(run_name=name):
        # Modelo
        mlf.log_model(model, name)

        # Parámetros
        mlflow.log_param("optimizer", model.optimizer.__class__.__name__)
        mlflow.log_param("loss", model.loss)
        mlflow.log_param("num_layers", len(model.layers))
        for i, layer in enumerate(model.layers):
            mlflow.log_param(f"layer_{i}_type", layer.__class__.__name__)
            mlflow.log_param(f"layer_{i}_units", layer.units if hasattr(layer, 'units') else "N/A")
            mlflow.log_param(f"layer_{i}_activation", layer.get_config().get('activation', 'N/A'))
            # Si la capa es de tipo Dropout, registrar el rate
            if layer.__class__.__name__ == 'Dropout':
                mlflow.log_param(f"layer_{i}_rate", layer.get_config().get('rate', 'N/A'))


        # Registrar métricas
        for metric_name, metric_values in history.history.items():
            for epoch, metric_value in enumerate(metric_values):
                mlflow.log_metric(metric_name, metric_value, step=epoch)

        # Gráficas
        mlf.log_plot(loss_grafic, "Loss_evolution_grafica.png")
        mlf.log_plot(accuracy_grafic, "Accuracy_evolution_grafica.png")
        mlf.log_plot(precision_grafic, "Precision_evolution_grafica.png")
        

        # Añadir tag al registro
        mlflow.set_tag("Tecnología", "Deep Learning")

# %%
# MLFlow
mlflow.set_tracking_uri("../../mlflow/")
mlflow.set_experiment("NPL-Tweets")
cargar_MLFlow()
# Out:
# INFO:tensorflow:Assets written to: ram://8551c5bd-6955-438d-9ab3-1104306fe085/assets
# 2023/10/30 18:45:07 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: C:\Users\enric\AppData\Local\Temp\tmp7m8yf7dg\model\model.pkl, flavor: sklearn), fall back to return ['scikit-learn==1.3.2', 'cloudpickle==2.2.1']. Set logging level to DEBUG to see the full traceback.

# %% [markdown]
# ### Gurdado local

# %%
dump(model, '../../models/'+name+'.joblib')
# Out:
# INFO:tensorflow:Assets written to: ram://82d42a8a-aba3-448a-b666-5f02eaaf8bf9/assets
# ['../../models/4_Keras.joblib']
